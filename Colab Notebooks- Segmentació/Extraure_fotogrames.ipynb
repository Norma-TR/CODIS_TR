# %% [markdown]
# Com que tenim el video al google drive, primer hem de poder accedir als continguts del drive executant aquest codi:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Guardarem 10 fotogrames per segon, com que el video té una durada de 58,17 segons, en total tindrem aproximadament 58,17*10 = 5817 fotogrames
FPS = 10

# %%
import cv2
import math

videoFile = "/content/drive/MyDrive/TR/CAPSULA_ENDOSCOPICA/BENITEZ PERULLES NORMA (921185B) 14 Feb 24_1.mpg"

cap = cv2.VideoCapture(videoFile)
frameRate = cap.get(5) #frame rate del video (25 fotogrames per segon)
x=1
while(cap.isOpened()):
    frameId = cap.get(1) #current frame number
    ret, frame = cap.read()
    if (ret != True):
        break
    if (frameId % math.floor(frameRate) == 0):
        print('Fotograma # {}'.format(frameId))
        print('Imatge # {}'.format(x))

        filename = '/content/drive/MyDrive/TR/CAPSULA_ENDOSCOPICA/test_images/image' +  str(int(x)) + ".jpg";x+=1
        #cv2.imwrite(filename, frame)

cap.release()
print ("Done!")
# Out:
# Streaming output truncated to the last 5000 lines.
# Imatge # 999
# Fotograma # 24975.0
# Imatge # 1000
# Fotograma # 25000.0
# Imatge # 1001
# Fotograma # 25025.0
# Imatge # 1002
# Fotograma # 25050.0
# Imatge # 1003
# Fotograma # 25075.0
# Imatge # 1004
# Fotograma # 25100.0
# Imatge # 1005
# Fotograma # 25125.0
# Imatge # 1006
# Fotograma # 25150.0
# Imatge # 1007
# Fotograma # 25175.0
# Imatge # 1008
# Fotograma # 25200.0
# Imatge # 1009
# Fotograma # 25225.0
# Imatge # 1010
# Fotograma # 25250.0
# Imatge # 1011
# Fotograma # 25275.0
# Imatge # 1012
# Fotograma # 25300.0
# Imatge # 1013
# Fotograma # 25325.0
# Imatge # 1014
# Fotograma # 25350.0
# Imatge # 1015
# Fotograma # 25375.0
# Imatge # 1016
# Fotograma # 25400.0
# Imatge # 1017
# Fotograma # 25425.0
# Imatge # 1018
# Fotograma # 25450.0
# Imatge # 1019
# Fotograma # 25475.0
# Imatge # 1020
# Fotograma # 25500.0
# Imatge # 1021
# Fotograma # 25525.0
# Imatge # 1022
# Fotograma # 25550.0
# Imatge # 1023
# ...

# %%
import cv2

# create video capture object
videoFile = "/content/drive/MyDrive/TR/CAPSULA_ENDOSCOPICA/BENITEZ PERULLES NORMA (921185B) 14 Feb 24_1.mpg"
cap = cv2.VideoCapture(videoFile)

# count the number of frames
fps = cap.get(cv2.CAP_PROP_FPS)
totalNoFrames = cap.get(cv2.CAP_PROP_FRAME_COUNT)
durationInSeconds = totalNoFrames // fps

print("Video Duration In Seconds:", durationInSeconds, "s")
# Out:
# Video Duration In Seconds: 2989.0 s

# %%
fps
# Out:
# 25.0

# %%
totalNoFrames
# Out:
# 74741.0
