# %% [markdown]
# # 1. Llegir imatge

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

from skimage import data
from skimage.filters import threshold_multiotsu
from skimage.io import imread

# Setting the font size for all plots.
matplotlib.rcParams['font.size'] = 9

# The input image.
I = imread('/content/drive/MyDrive/TR/CAPSULA_ENDOSCOPICA/test_images/image1519.jpg')

# %% [markdown]
# Mirem les dimensions de la imatge

# %%
I.shape
# Out:
# (576, 576, 3)

# %% [markdown]
# Mirem quants pixels te la imatge

# %%
I.shape[0]*I.shape[1]
# Out:
# 331776

# %%
I.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# Mostrem la imatge original en color

# %%
from skimage.io import imshow

imshow(I)

# %% [markdown]
# en aquesta imatge tenim una imatge de 576 files, 576 columnes i 3 canals de color (RGB)

# %%
I.shape
# Out:
# (576, 576, 3)

# %% [markdown]
# # 2. Funció per segmentar la imatge RGB
#
# La funció té com a entrad la imatge RGB I i retorna la imatge segmentada L

# %%
import numpy as np
from sklearn.cluster import KMeans

X = np.reshape(I,(I.shape[0]*I.shape[1],I.shape[2]))
labels = KMeans(n_clusters=4).fit_predict(X)
L = np.reshape(labels,(I.shape[0],I.shape[1]))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# # 3. grafiquem la imatge original i el resultat de la segmentació

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(121)
ax1 = plt.imshow(I)

ax2 = fig.add_subplot(122)
ax2 = plt.imshow(L)

# %%
L.shape
# Out:
# (576, 576)

# %%
np.unique(L)
# Out:
# array([0, 1, 2, 3], dtype=int32)
