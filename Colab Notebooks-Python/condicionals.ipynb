# %% [markdown]
# Instruccions per controlar el fluxe del programa

# %%
nota= 1.9
if nota < 5:
  print('suspés')
else:
  print('aprovat')
# Out:
# suspés

# %% [markdown]
# Fent servir formularis per inrtoduir les dades al programa

# %%
# @title Number fields
nota = 5.1 # @param {type:"number"}

if nota < 5:
  print('suspés')
else:
  print('aprovat')
# Out:
# aprovat

# %%
nota_slider = 5.4 # @param {type:"slider", min:0, max:10, step:0.1}

if nota_slider < 5:
  print('suspés')
else:
  print('aprovat')
# Out:
# aprovat
