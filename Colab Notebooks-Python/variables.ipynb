# %% [markdown]
# Ara farem un petit programa en Python que només conté una única fila i que escriu per pantalla amb la funció print la cadena de caràcters 'Aquesta és una cel.la de Python'

# %%
print('Aquesta és una cel.la de Python')
# Out:
# Aquesta és una cel.la de Python

# %% [markdown]
# Aquesta és una cel.la de text

# %% [markdown]
# Ara farem un programa en Python que assigna el valor 0.314 a la variable z (però no imprimeix res)

# %%
z = 0.314

# %% [markdown]
# Ara assignem el valor i després demanem que ho imprimeixi per pantalla

# %%
z = 0.314
print(z)
# Out:
# 0.314

# %% [markdown]
# Dues assignacions a la variable z consequtives

# %%
z = 19
print(z)
z = 23
print(z)
# Out:
# 19
# 23

# %% [markdown]
# Podem treure per pantalla el valor d'una variable dins d'una cadena de caràcters

# %%
z = 19
print('El primer valor de la variable z és {}'.format(z))
z = 23
print('El segon valor de la variable z és {}'.format(z))
# Out:
# El primer valor de la variable z és 19
# El segon valor de la variable z és 23

# %% [markdown]
# Aquesta és una variable del tipus vector

# %%
v = [3,2,-1,0]
print(v)
# Out:
# [3, 2, -1, 0]

# %% [markdown]
# Per accedir a una de les components del vector hem de dir quina és

# %%
print('El valor del primer component del vector és {}'.format(v[0]))
# Out:
# El valor del primer component del vector és 3

# %%
print('El valor del segon component del vector és {}'.format(v[1]))
# Out:
# El valor del segon component del vector és 2

# %% [markdown]
# Ara una matriu de dues files i dues colunes

# %%
M  = [[2,3],[4,5]]

# %%
M[0][0]
# Out:
# 2

# %%
print('El component de la segona fila i segona columna de la matriu és {}'.format(M[1][1]))
# Out:
# El component de la segona fila i segona columna de la matriu és 5
